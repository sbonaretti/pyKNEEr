# %% [markdown]
# ## [pyKNEEr](https://github.com/sbonaretti/pyKNEEr)

# %% [markdown]
# # [Segmentation quality](https://sbonaretti.github.io/pyKNEEr/segmentation.html)

# %% [markdown]
# Segmentation quality is evaluated using 3 overlap agreement measures [1]:
# - Dice coefficient
# - Jaccard coefficient
# - Volume similarity

# %% [markdown]
# ## Import packages

# %%
# %load_ext autoreload 
# %autoreload 2

# %%
from pykneer import pykneer_io                  as io
from pykneer import segmentation_quality_for_nb as sq

# %% [markdown]
# ## Image information

# %% [markdown]
# Input and output:
# - `input_file_name` contains the list of the masks segmented using pyKNEEr and of ground truth masks
# - `output_file_name` contains the table of the overlap coefficients

# %%
input_file_name  = "./image_list_segmentation_quality_OAI2_FU.txt"
output_file_name = "overlapCoeff_OAI2_FU.csv"

# %% [markdown]
# #### Reading image data
# - `image_data` is a dictionary (or struct), where each cell corresponds to an image. For each image, information such as paths and file names are stored

# %%
image_data = io.load_image_data_segmentation_quality(input_file_name)
# Out:
# -> image information loaded

# %% [markdown]
# ## Calculate overlap coefficients

# %%
dice_coeff, jacc_coeff, vol_simil = sq.compute_overlap(image_data)

# %% [markdown]
# ## Visualizing overlap coefficients
#
# The values of overlap coefficient are visualized as:
# - a GRAPH, to visually observe the trend of the dataset
# - a TABLE, to observe the numerical values

# %% [markdown]
# #### GRAPH: Dots represent the coefficient value

# %%
sq.overlap_coeff_graph(image_data, dice_coeff, jacc_coeff, vol_simil)

# %% [markdown]
# #### TABLE: Overlap coefficients per image
# The table is saved as a .csv file for subsequent analyisis

# %%
coeff = sq.overlap_coeff_table(image_data, dice_coeff, jacc_coeff, vol_simil, output_file_name)
display(coeff)
# Out:
# Table saved as: overlapCoeff_OAI2_FU.csv
#           Subjects  DiceCoeff  JaccardCoeff  VolumeSimilarity
# 1   001_FU_prep_fc       0.70          0.53             -0.08
# 2   002_FU_prep_fc       0.76          0.61             -0.08
# 3   003_FU_prep_fc       0.75          0.60             -0.26
# 4   004_FU_prep_fc       0.74          0.58             -0.15
# 5   005_FU_prep_fc       0.78          0.63             -0.18
# 6   006_FU_prep_fc       0.01          0.01             -0.56
# 7   007_FU_prep_fc       0.72          0.56             -0.07
# 8   008_FU_prep_fc       0.70          0.54              0.03
# 9   009_FU_prep_fc       0.71          0.56              0.09
# 10  010_FU_prep_fc       0.70          0.54              0.01
# 11  011_FU_prep_fc       0.75          0.60             -0.11
# 12  012_FU_prep_fc       0.72          0.56             -0.00
# 13  013_FU_prep_fc       0.78          0.64             -0.02
# 14  014_FU_prep_fc       0.77          0.63             -0.11
# 15  015_FU_prep_fc       0.82          0.70             -0.10
# 16  016_FU_prep_fc       0.83          0.70             -0.11
# 17  017_FU_prep_fc       0.70          0.54             -0.04
# 18  018_FU_prep_fc       0.75          0.61             -0.21
# 19  019_FU_prep_fc       0.70          0.54             -0.02
# 20  020_FU_prep_fc       0.74          0.59             -0.13
# 21  021_FU_prep_fc       0.72          0.56             -0.33
# 22  022_FU_prep_fc       0.65          0.48             -0.17
# 23  023_FU_prep_fc       0.75          0.60             -0.11
# 24  024_FU_prep_fc       0.34          0.20             -0.44
# 25  025_FU_prep_fc       0.69          0.52             -0.04
# 26  026_FU_prep_fc       0.69          0.53              0.21
# 27  027_FU_prep_fc       0.76          0.61             -0.21
# 28  028_FU_prep_fc       0.70          0.54             -0.01
# 29  029_FU_prep_fc       0.73          0.58             -0.14
# 30  030_FU_prep_fc       0.70          0.54             -0.07
# 31  031_FU_prep_fc       0.56          0.39             -0.40
# 32  032_FU_prep_fc       0.75          0.61             -0.13
# 33  033_FU_prep_fc       0.64          0.48             -0.17
# 34  034_FU_prep_fc       0.67          0.50             -0.28
# 35  035_FU_prep_fc       0.68          0.52             -0.28
# 36  036_FU_prep_fc       0.72          0.57             -0.15
# 37  037_FU_prep_fc       0.79          0.65             -0.14
# 38  038_FU_prep_fc       0.72          0.57              0.01
# 39  039_FU_prep_fc       0.73          0.58             -0.24
# 40  040_FU_prep_fc       0.74          0.59             -0.05
# 41  041_FU_prep_fc       0.71          0.54             -0.06
# 42  042_FU_prep_fc       0.72          0.57             -0.08
# 43  043_FU_prep_fc       0.73          0.57             -0.13
# 44  044_FU_prep_fc       0.76          0.61             -0.21
# 45  045_FU_prep_fc       0.75          0.60             -0.05
# 46  046_FU_prep_fc       0.75          0.60             -0.06
# 47  047_FU_prep_fc       0.74          0.59              0.05
# 48  048_FU_prep_fc       0.77          0.63             -0.06
# 49  049_FU_prep_fc       0.74          0.58             -0.13
# 50  050_FU_prep_fc       0.71          0.56             -0.07
# 51  051_FU_prep_fc       0.63          0.46              0.00
# 52  052_FU_prep_fc       0.77          0.63              0.06
# 53  053_FU_prep_fc       0.63          0.46              0.13
# 54  054_FU_prep_fc       0.79          0.65             -0.14
# 55  055_FU_prep_fc       0.78          0.64             -0.12
# 56  056_FU_prep_fc       0.74          0.58              0.03
# 57  057_FU_prep_fc       0.41          0.26             -0.27
# 58  058_FU_prep_fc       0.70          0.54             -0.11
# 59  059_FU_prep_fc       0.76          0.61             -0.00
# 60  060_FU_prep_fc       0.65          0.48             -0.07
# 61  061_FU_prep_fc       0.68          0.52              0.07
# 62  062_FU_prep_fc       0.74          0.59              0.01
# 63  063_FU_prep_fc       0.69          0.52             -0.01
# 64  064_FU_prep_fc       0.69          0.53             -0.12
# 65  065_FU_prep_fc       0.79          0.65             -0.04
# 66  066_FU_prep_fc       0.73          0.58             -0.04
# 67  067_FU_prep_fc       0.72          0.56             -0.16
# 68  068_FU_prep_fc       0.67          0.51             -0.21
# 69  069_FU_prep_fc       0.75          0.60             -0.10
# 70  070_FU_prep_fc       0.71          0.55             -0.24
# 71  071_FU_prep_fc       0.72          0.56             -0.11
# 72  072_FU_prep_fc       0.70          0.54             -0.09
# 73  073_FU_prep_fc       0.75          0.60             -0.11
# 74  074_FU_prep_fc       0.73          0.57             -0.04
# 75  075_FU_prep_fc       0.79          0.66             -0.10
# 76  076_FU_prep_fc       0.66          0.49              0.30
# 77  077_FU_prep_fc       0.64          0.47             -0.10
# 78  078_FU_prep_fc       0.73          0.58              0.02
# 79  079_FU_prep_fc       0.80          0.66             -0.09
# 80  080_FU_prep_fc       0.64          0.47             -0.25
# 81  081_FU_prep_fc       0.71          0.55             -0.20
# 82  082_FU_prep_fc       0.70          0.54             -0.02
# 83  083_FU_prep_fc       0.68          0.52              0.12
# 84  084_FU_prep_fc       0.59          0.42             -0.24
# 85  085_FU_prep_fc       0.78          0.64             -0.05
# 86  086_FU_prep_fc       0.70          0.54             -0.04
# 87  087_FU_prep_fc       0.73          0.57              0.03
# 88  088_FU_prep_fc       0.75          0.60             -0.13

# %% [markdown]
# ### References

# %% [markdown]
# [1] Tustison N.J., Gee J.C. [*Introducing Dice, Jaccard, and Other Label Overlap Measures To ITK*](http://insight-journal.org/browse/publication/707) The Insight Journal. July-December. 2009.

# %% [markdown]
# ### Dependencies

# %%
# %load_ext watermark
# %watermark -v -m -p SimpleITK,matplotlib,numpy,pandas,plotnine
# Out:
# CPython 3.7.1
# IPython 6.5.0
#
# SimpleITK unknown
# matplotlib 2.2.3
# numpy 1.15.1
# pandas 0.23.4
# plotnine not installed
#
# compiler   : Clang 4.0.1 (tags/RELEASE_401/final)
# system     : Darwin
# release    : 17.7.0
# machine    : x86_64
# processor  : i386
# CPU cores  : 4
# interpreter: 64bit
