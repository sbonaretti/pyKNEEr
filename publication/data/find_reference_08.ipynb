# %% [markdown]
# ## [pyKNEEr](https://github.com/sbonaretti/pyKNEEr)

# %% [markdown]
# # [Find Reference Image for Atlas-based Segmentation of MR Knee Images](https://sbonaretti.github.io/pyKNEEr/segmentation.html)
# Content under Creative Commons Attribution license CC-BY-NC 4.0
# Code under GNU-GPL v3 License
# © 2019 Serena Bonaretti
# ---

# %% [markdown]
# The reference image is found in an iterative way, as the image whose vector field is the closest to the average of the vector fields at that iteration. Iterations stop at convergence or at a defined iteration number.
#
# The image used to initialize the first iteration was determined using a random function, which was initialized with an arbitrarily chosen seed number for reproducibility ([here](https://github.com/sbonaretti/pyKNEEr/blob/master/code/pykneer/find_reference_random_gen.py))

# %% [markdown]
# ---

# %% [markdown]
# *Automatic data download for the reproducibility of this notebook:*
# - Download input images from Zenodo and image file list from GitHub:

# %%
import os
import wget
from zipfile import ZipFile

# %%
# local folder  
local_folder_name  = "./OAI1/"
# Zenodo variables
input_URL          = "https://zenodo.org/record/2583184/files/"
zipped_folder_name = "OAI1_findingReference.zip" 
# GitHub variables
raw_url            = "https://raw.githubusercontent.com/sbonaretti/pyKNEEr/master/publication/data/"
input_file_name    = "image_list_find_reference_08.txt"

# %%
# create local folder for dataset
if not os.path.isdir(local_folder_name):
    os.mkdir(local_folder_name)
    print ("folder " + local_folder_name + " created")

# %%
# download zipped folder from Zenodo
wget.download(input_URL + zipped_folder_name, local_folder_name + zipped_folder_name)

# %%
# unzip folder
with ZipFile(local_folder_name + zipped_folder_name, 'r') as zip: 
    zip.extractall(local_folder_name)

# %%
# download input file from GitHub
wget.download(raw_url + input_file_name, "./" + input_file_name)

# %% [markdown]
# ---

# %% [markdown]
# ## Import packages

# %%
# %load_ext autoreload 
# %autoreload 2

# %%
from pykneer import pykneer_io            as io
from pykneer import find_reference_for_nb as find

# %% [markdown]
# ## Image information

# %% [markdown]
# Inputs:
# - `input_file_name` contains the list of the preprocessed images of the dataset
# - `n_of_cores` is the number of cores used for computations (computations are parallelized for speed)

# %%
# input_file_name = "./image_list_find_reference_08.txt" # commented out because downloaded from GitHub
n_of_cores      = 10

# %% [markdown]
# #### Read image data
# - `image_data` is a dictionary (or struct), where each cell corresponds to an image. For each image, information such as paths and file names are stored

# %%
image_data = io.load_image_data_find_reference(input_file_name)
# Out:
# -> image information loaded

# %% [markdown]
# ## Find reference
# Run the convergence study to find the reference as the image whose vector field is the closest to the average of the vector fields at that iteration

# %%
reference_names, min_distances = find.find_reference(image_data, n_of_cores)
# Out:
# -> Iteration: 1
#    1. Preparing reference YR04_08_DESS_prep.mha
#    2. Registering images to current reference
# -> Vector fields calculated
#    3. Computing new reference
#     YR04_01_DESS_prep_VF.mha
#       norm before normalization: 3001.695
#       norm after normalization: 0.000760706040462262
#       number of image voxels: 23592960
#       snumber of masked voxels: 3945933
#     YR04_02_DESS_prep_VF.mha
#       norm before normalization: 5007.4873
#       norm after normalization: 0.0012690249187422848
#       number of image voxels: 23592960
#       snumber of masked voxels: 3945933
#     YR04_03_DESS_prep_VF.mha
#       norm before normalization: 5470.292
#       norm after normalization: 0.00138631142297335
#       number of image voxels: 23592960
#       snumber of masked voxels: 3945933
#     YR04_04_DESS_prep_VF.mha
#       norm before normalization: 5313.222
#       norm after normalization: 0.0013465059259670019
#       number of image voxels: 23592960
#       snumber of masked voxels: 3945933
#     YR04_05_DESS_prep_VF.mha
#       norm before normalization: 5338.1836
#       norm after normalization: 0.001352831787501207
#       number of image voxels: 23592960
#       snumber of masked voxels: 3945933
#     YR04_06_DESS_prep_VF.mha
#       norm before normalization: 7506.435
#       norm after normalization: 0.0019023219752068142
#       number of image voxels: 23592960
#       snumber of masked voxels: 3945933
#     YR04_07_DESS_prep_VF.mha
#       norm before normalization: 5076.762
#       norm after normalization: 0.0012865809447426628
#       number of image voxels: 23592960
#       snumber of masked voxels: 3945933
#     YR04_08_DESS_prep_VF.mha
#       norm before normalization: 3115.429
#       norm after normalization: 0.0007895291063173463
#       number of image voxels: 23592960
#       snumber of masked voxels: 3945933
#     YR04_09_DESS_prep_VF.mha
#       norm before normalization: 1597.3046
#       norm after normalization: 0.0004047976905410425
#       number of image voxels: 23592960
#       snumber of masked voxels: 3945933
#     YR04_10_DESS_prep_VF.mha
#       norm before normalization: 11095.336
#       norm after normalization: 0.002811840935337726
#       number of image voxels: 23592960
#       snumber of masked voxels: 3945933
#     YR04_11_DESS_prep_VF.mha
#       norm before normalization: 6570.6143
#       norm after normalization: 0.0016651611311729064
#       number of image voxels: 23592960
#       snumber of masked voxels: 3945933
#     YR04_12_DESS_prep_VF.mha
#       norm before normalization: 2510.5452
#       norm after normalization: 0.0006362361362992288
#       number of image voxels: 23592960
#       snumber of masked voxels: 3945933
#     YR04_13_DESS_prep_VF.mha
#       norm before normalization: 4039.277
#       norm after normalization: 0.0010236557740867305
#       number of image voxels: 23592960
#       snumber of masked voxels: 3945933
#     YR04_14_DESS_prep_VF.mha
#       norm before normalization: 9509.227
#       norm after normalization: 0.002409880391405531
#       number of image voxels: 23592960
#       snumber of masked voxels: 3945933
#     YR04_15_DESS_prep_VF.mha
#       norm before normalization: 13297.794
#       norm after normalization: 0.003369999932921441
#       number of image voxels: 23592960
#       snumber of masked voxels: 3945933
#     YR04_16_DESS_prep_VF.mha
#       norm before normalization: 9254.079
#       norm after normalization: 0.0023452195213559124
#       number of image voxels: 23592960
#       snumber of masked voxels: 3945933
#     YR04_17_DESS_prep_VF.mha
#       norm before normalization: 4565.0464
#       norm after normalization: 0.0011568991127621148
#       number of image voxels: 23592960
#       snumber of masked voxels: 3945933
#     YR04_18_DESS_prep_VF.mha
#       norm before normalization: 3408.2844
#       norm after normalization: 0.0008637461466852389
#       number of image voxels: 23592960
#       snumber of masked voxels: 3945933
#     YR04_19_DESS_prep_VF.mha
#       norm before normalization: 1977.7682
#       norm after normalization: 0.0005012168702500935
#       number of image voxels: 23592960
#       snumber of masked voxels: 3945933
#    -> Distances to average field are: [0.00076071 0.00126902 0.00138631 0.00134651 0.00135283 0.00190232
#  0.00128658 0.00078953 0.0004048  0.00281184 0.00166516 0.00063624
#  0.00102366 0.00240988 0.00337    0.00234522 0.0011569  0.00086375
#  0.00050122]
#    -> Minimum distance is 0.00040480
#    -> Reference of next iteration is YR04_09_DESS_prep.mha
# -> The total time for iteration 1 was 696 seconds (about 11 min)
# -> Iteration: 2
#    1. Preparing reference YR04_09_DESS_prep.mha
#    2. Registering images to current reference
# -> Vector fields calculated
#    3. Computing new reference
#     YR04_01_DESS_prep_VF.mha
#       norm before normalization: 1862.1902
#       norm after normalization: 0.00045668511504417153
#       number of image voxels: 23592960
#       snumber of masked voxels: 4077624
#     YR04_02_DESS_prep_VF.mha
#       norm before normalization: 2142.7751
#       norm after normalization: 0.0005254960110310257
#       number of image voxels: 23592960
#       snumber of masked voxels: 4077624
#     YR04_03_DESS_prep_VF.mha
#       norm before normalization: 1309.4329
#       norm after normalization: 0.0003211264357204404
#       number of image voxels: 23592960
#       snumber of masked voxels: 4077624
#     YR04_04_DESS_prep_VF.mha
#       norm before normalization: 2231.5098
#       norm after normalization: 0.0005472573649814205
#       number of image voxels: 23592960
#       snumber of masked voxels: 4077624
#     YR04_05_DESS_prep_VF.mha
#       norm before normalization: 1377.5864
#       norm after normalization: 0.00033784047420293045
#       number of image voxels: 23592960
#       snumber of masked voxels: 4077624
#     YR04_06_DESS_prep_VF.mha
#       norm before normalization: 11661.962
#       norm after normalization: 0.002859989521854516
#       number of image voxels: 23592960
#       snumber of masked voxels: 4077624
#     YR04_07_DESS_prep_VF.mha
#       norm before normalization: 1910.7982
#       norm after normalization: 0.00046860579047343197
#       number of image voxels: 23592960
#       snumber of masked voxels: 4077624
#     YR04_08_DESS_prep_VF.mha
#       norm before normalization: 1159.8011
#       norm after normalization: 0.0002844306261344689
#       number of image voxels: 23592960
#       snumber of masked voxels: 4077624
#     YR04_09_DESS_prep_VF.mha
#       norm before normalization: 655.5014
#       norm after normalization: 0.00016075572534608235
#       number of image voxels: 23592960
#       snumber of masked voxels: 4077624
#     YR04_10_DESS_prep_VF.mha
#       norm before normalization: 11114.051
#       norm after normalization: 0.0027256193266593487
#       number of image voxels: 23592960
#       snumber of masked voxels: 4077624
#     YR04_11_DESS_prep_VF.mha
#       norm before normalization: 4865.434
#       norm after normalization: 0.0011932032188429463
#       number of image voxels: 23592960
#       snumber of masked voxels: 4077624
#     YR04_12_DESS_prep_VF.mha
#       norm before normalization: 3189.215
#       norm after normalization: 0.0007821258379611816
#       number of image voxels: 23592960
#       snumber of masked voxels: 4077624
#     YR04_13_DESS_prep_VF.mha
#       norm before normalization: 417.36624
#       norm after normalization: 0.00010235525429884612
#       number of image voxels: 23592960
#       snumber of masked voxels: 4077624
#     YR04_14_DESS_prep_VF.mha
#       norm before normalization: 3317.572
#       norm after normalization: 0.0008136042022227589
#       number of image voxels: 23592960
#       snumber of masked voxels: 4077624
#     YR04_15_DESS_prep_VF.mha
#       norm before normalization: 3453.731
#       norm after normalization: 0.0008469959361214398
#       number of image voxels: 23592960
#       snumber of masked voxels: 4077624
#     YR04_16_DESS_prep_VF.mha
#       norm before normalization: 1904.218
#       norm after normalization: 0.0004669920565452148
#       number of image voxels: 23592960
#       snumber of masked voxels: 4077624
#     YR04_17_DESS_prep_VF.mha
#       norm before normalization: 3078.4646
#       norm after normalization: 0.0007549652934182689
#       number of image voxels: 23592960
#       snumber of masked voxels: 4077624
#     YR04_18_DESS_prep_VF.mha
#       norm before normalization: 1403.7797
#       norm after normalization: 0.00034426412613961893
#       number of image voxels: 23592960
#       snumber of masked voxels: 4077624
#     YR04_19_DESS_prep_VF.mha
#       norm before normalization: 2881.9082
#       norm after normalization: 0.0007067616345021022
#       number of image voxels: 23592960
#       snumber of masked voxels: 4077624
#    -> Distances to average field are: [0.00045669 0.0005255  0.00032113 0.00054726 0.00033784 0.00285999
#  0.00046861 0.00028443 0.00016076 0.00272562 0.0011932  0.00078213
#  0.00010236 0.0008136  0.000847   0.00046699 0.00075497 0.00034426
#  0.00070676]
#    -> Minimum distance is 0.00010236
#    -> Reference of next iteration is YR04_13_DESS_prep.mha
# -> The total time for iteration 2 was 698 seconds (about 11 min)
# -> Iteration: 3
#    1. Preparing reference YR04_13_DESS_prep.mha
#    2. Registering images to current reference
# -> Vector fields calculated
#    3. Computing new reference
#     YR04_01_DESS_prep_VF.mha
#       norm before normalization: 1889.0062
#       norm after normalization: 0.0004616239347643557
#       number of image voxels: 23592960
#       snumber of masked voxels: 4092089
#     YR04_02_DESS_prep_VF.mha
#       norm before normalization: 2392.2004
#       norm after normalization: 0.0005845914982428596
#       number of image voxels: 23592960
#       snumber of masked voxels: 4092089
#     YR04_03_DESS_prep_VF.mha
#       norm before normalization: 2143.939
#       norm after normalization: 0.0005239228581889959
#       number of image voxels: 23592960
#       snumber of masked voxels: 4092089
#     YR04_04_DESS_prep_VF.mha
#       norm before normalization: 2489.0796
#       norm after normalization: 0.0006082662400167128
#       number of image voxels: 23592960
#       snumber of masked voxels: 4092089
#     YR04_05_DESS_prep_VF.mha
#       norm before normalization: 2438.2449
#       norm after normalization: 0.000595843558888107
#       number of image voxels: 23592960
#       snumber of masked voxels: 4092089
#     YR04_06_DESS_prep_VF.mha
#       norm before normalization: 8430.819
#       norm after normalization: 0.0020602727203483354
#       number of image voxels: 23592960
#       snumber of masked voxels: 4092089
#     YR04_07_DESS_prep_VF.mha
#       norm before normalization: 2119.3665
#       norm after normalization: 0.0005179179766320149
#       number of image voxels: 23592960
#       snumber of masked voxels: 4092089
#     YR04_08_DESS_prep_VF.mha
#       norm before normalization: 928.51746
#       norm after normalization: 0.00022690548911685144
#       number of image voxels: 23592960
#       snumber of masked voxels: 4092089
#     YR04_09_DESS_prep_VF.mha
#       norm before normalization: 1651.5046
#       norm after normalization: 0.0004035847310925728
#       number of image voxels: 23592960
#       snumber of masked voxels: 4092089
#     YR04_10_DESS_prep_VF.mha
#       norm before normalization: 8687.846
#       norm after normalization: 0.0021230832719241932
#       number of image voxels: 23592960
#       snumber of masked voxels: 4092089
#     YR04_11_DESS_prep_VF.mha
#       norm before normalization: 5608.1133
#       norm after normalization: 0.0013704768594353643
#       number of image voxels: 23592960
#       snumber of masked voxels: 4092089
#     YR04_12_DESS_prep_VF.mha
#       norm before normalization: 2251.3474
#       norm after normalization: 0.0005501706859526699
#       number of image voxels: 23592960
#       snumber of masked voxels: 4092089
#     YR04_13_DESS_prep_VF.mha
#       norm before normalization: 1726.666
#       norm after normalization: 0.00042195221453516775
#       number of image voxels: 23592960
#       snumber of masked voxels: 4092089
#     YR04_14_DESS_prep_VF.mha
#       norm before normalization: 3949.594
#       norm after normalization: 0.0009651779309151451
#       number of image voxels: 23592960
#       snumber of masked voxels: 4092089
#     YR04_15_DESS_prep_VF.mha
#       norm before normalization: 1477.488
#       norm after normalization: 0.0003610596047909454
#       number of image voxels: 23592960
#       snumber of masked voxels: 4092089
#     YR04_16_DESS_prep_VF.mha
#       norm before normalization: 2732.0137
#       norm after normalization: 0.0006676330040414566
#       number of image voxels: 23592960
#       snumber of masked voxels: 4092089
#     YR04_17_DESS_prep_VF.mha
#       norm before normalization: 15281.137
#       norm after normalization: 0.0037343119171528282
#       number of image voxels: 23592960
#       snumber of masked voxels: 4092089
#     YR04_18_DESS_prep_VF.mha
#       norm before normalization: 1414.5166
#       norm after normalization: 0.00034567102562102145
#       number of image voxels: 23592960
#       snumber of masked voxels: 4092089
#     YR04_19_DESS_prep_VF.mha
#       norm before normalization: 2424.2627
#       norm after normalization: 0.0005924266787238743
#       number of image voxels: 23592960
#       snumber of masked voxels: 4092089
#    -> Distances to average field are: [0.00046162 0.00058459 0.00052392 0.00060827 0.00059584 0.00206027
#  0.00051792 0.00022691 0.00040358 0.00212308 0.00137048 0.00055017
#  0.00042195 0.00096518 0.00036106 0.00066763 0.00373431 0.00034567
#  0.00059243]
#    -> Minimum distance is 0.00022691
#    -> Reference of next iteration is YR04_08_DESS_prep.mha
# -> The total time for iteration 3 was 698 seconds (about 11 min)
# -> Iteration: 4
#    1. Preparing reference YR04_08_DESS_prep.mha
#    2. Registering images to current reference
# -> Vector fields calculated
#    3. Computing new reference
#     YR04_01_DESS_prep_VF.mha
#       norm before normalization: 3001.695
#       norm after normalization: 0.000760706040462262
#       number of image voxels: 23592960
#       snumber of masked voxels: 3945933
#     YR04_02_DESS_prep_VF.mha
#       norm before normalization: 5007.4873
#       norm after normalization: 0.0012690249187422848
#       number of image voxels: 23592960
#       snumber of masked voxels: 3945933
#     YR04_03_DESS_prep_VF.mha
#       norm before normalization: 5470.292
#       norm after normalization: 0.00138631142297335
#       number of image voxels: 23592960
#       snumber of masked voxels: 3945933
#     YR04_04_DESS_prep_VF.mha
#       norm before normalization: 5313.222
#       norm after normalization: 0.0013465059259670019
#       number of image voxels: 23592960
#       snumber of masked voxels: 3945933
#     YR04_05_DESS_prep_VF.mha
#       norm before normalization: 5338.1836
#       norm after normalization: 0.001352831787501207
#       number of image voxels: 23592960
#       snumber of masked voxels: 3945933
#     YR04_06_DESS_prep_VF.mha
#       norm before normalization: 7506.435
#       norm after normalization: 0.0019023219752068142
#       number of image voxels: 23592960
#       snumber of masked voxels: 3945933
#     YR04_07_DESS_prep_VF.mha
#       norm before normalization: 5076.762
#       norm after normalization: 0.0012865809447426628
#       number of image voxels: 23592960
#       snumber of masked voxels: 3945933
#     YR04_08_DESS_prep_VF.mha
#       norm before normalization: 3115.429
#       norm after normalization: 0.0007895291063173463
#       number of image voxels: 23592960
#       snumber of masked voxels: 3945933
#     YR04_09_DESS_prep_VF.mha
#       norm before normalization: 1597.3046
#       norm after normalization: 0.0004047976905410425
#       number of image voxels: 23592960
#       snumber of masked voxels: 3945933
#     YR04_10_DESS_prep_VF.mha
#       norm before normalization: 11095.336
#       norm after normalization: 0.002811840935337726
#       number of image voxels: 23592960
#       snumber of masked voxels: 3945933
#     YR04_11_DESS_prep_VF.mha
#       norm before normalization: 6570.6143
#       norm after normalization: 0.0016651611311729064
#       number of image voxels: 23592960
#       snumber of masked voxels: 3945933
#     YR04_12_DESS_prep_VF.mha
#       norm before normalization: 2510.5452
#       norm after normalization: 0.0006362361362992288
#       number of image voxels: 23592960
#       snumber of masked voxels: 3945933
#     YR04_13_DESS_prep_VF.mha
#       norm before normalization: 4039.277
#       norm after normalization: 0.0010236557740867305
#       number of image voxels: 23592960
#       snumber of masked voxels: 3945933
#     YR04_14_DESS_prep_VF.mha
#       norm before normalization: 9509.227
#       norm after normalization: 0.002409880391405531
#       number of image voxels: 23592960
#       snumber of masked voxels: 3945933
#     YR04_15_DESS_prep_VF.mha
#       norm before normalization: 13297.794
#       norm after normalization: 0.003369999932921441
#       number of image voxels: 23592960
#       snumber of masked voxels: 3945933
#     YR04_16_DESS_prep_VF.mha
#       norm before normalization: 9254.079
#       norm after normalization: 0.0023452195213559124
#       number of image voxels: 23592960
#       snumber of masked voxels: 3945933
#     YR04_17_DESS_prep_VF.mha
#       norm before normalization: 4565.0464
#       norm after normalization: 0.0011568991127621148
#       number of image voxels: 23592960
#       snumber of masked voxels: 3945933
#     YR04_18_DESS_prep_VF.mha
#       norm before normalization: 3408.2844
#       norm after normalization: 0.0008637461466852389
#       number of image voxels: 23592960
#       snumber of masked voxels: 3945933
#     YR04_19_DESS_prep_VF.mha
#       norm before normalization: 1977.7682
#       norm after normalization: 0.0005012168702500935
#       number of image voxels: 23592960
#       snumber of masked voxels: 3945933
#    -> Distances to average field are: [0.00076071 0.00126902 0.00138631 0.00134651 0.00135283 0.00190232
#  0.00128658 0.00078953 0.0004048  0.00281184 0.00166516 0.00063624
#  0.00102366 0.00240988 0.00337    0.00234522 0.0011569  0.00086375
#  0.00050122]
#    -> Minimum distance is 0.00040480
#    -> Reference of next iteration is YR04_09_DESS_prep.mha
# -> The total time for iteration 4 was 695 seconds (about 11 min)
# -> Iteration: 5
#    1. Preparing reference YR04_09_DESS_prep.mha
#    2. Registering images to current reference
# -> Vector fields calculated
#    3. Computing new reference
#     YR04_01_DESS_prep_VF.mha
#       norm before normalization: 1862.1902
#       norm after normalization: 0.00045668511504417153
#       number of image voxels: 23592960
#       snumber of masked voxels: 4077624
#     YR04_02_DESS_prep_VF.mha
#       norm before normalization: 2142.7751
#       norm after normalization: 0.0005254960110310257
#       number of image voxels: 23592960
#       snumber of masked voxels: 4077624
#     YR04_03_DESS_prep_VF.mha
#       norm before normalization: 1309.4329
#       norm after normalization: 0.0003211264357204404
#       number of image voxels: 23592960
#       snumber of masked voxels: 4077624
#     YR04_04_DESS_prep_VF.mha
#       norm before normalization: 2231.5098
#       norm after normalization: 0.0005472573649814205
#       number of image voxels: 23592960
#       snumber of masked voxels: 4077624
#     YR04_05_DESS_prep_VF.mha
#       norm before normalization: 1377.5864
#       norm after normalization: 0.00033784047420293045
#       number of image voxels: 23592960
#       snumber of masked voxels: 4077624
#     YR04_06_DESS_prep_VF.mha
#       norm before normalization: 11661.962
#       norm after normalization: 0.002859989521854516
#       number of image voxels: 23592960
#       snumber of masked voxels: 4077624
#     YR04_07_DESS_prep_VF.mha
#       norm before normalization: 1910.7982
#       norm after normalization: 0.00046860579047343197
#       number of image voxels: 23592960
#       snumber of masked voxels: 4077624
#     YR04_08_DESS_prep_VF.mha
#       norm before normalization: 1159.8011
#       norm after normalization: 0.0002844306261344689
#       number of image voxels: 23592960
#       snumber of masked voxels: 4077624
#     YR04_09_DESS_prep_VF.mha
#       norm before normalization: 655.5014
#       norm after normalization: 0.00016075572534608235
#       number of image voxels: 23592960
#       snumber of masked voxels: 4077624
#     YR04_10_DESS_prep_VF.mha
#       norm before normalization: 11114.051
#       norm after normalization: 0.0027256193266593487
#       number of image voxels: 23592960
#       snumber of masked voxels: 4077624
#     YR04_11_DESS_prep_VF.mha
#       norm before normalization: 4865.434
#       norm after normalization: 0.0011932032188429463
#       number of image voxels: 23592960
#       snumber of masked voxels: 4077624
#     YR04_12_DESS_prep_VF.mha
#       norm before normalization: 3189.215
#       norm after normalization: 0.0007821258379611816
#       number of image voxels: 23592960
#       snumber of masked voxels: 4077624
#     YR04_13_DESS_prep_VF.mha
#       norm before normalization: 417.36624
#       norm after normalization: 0.00010235525429884612
#       number of image voxels: 23592960
#       snumber of masked voxels: 4077624
#     YR04_14_DESS_prep_VF.mha
#       norm before normalization: 3317.572
#       norm after normalization: 0.0008136042022227589
#       number of image voxels: 23592960
#       snumber of masked voxels: 4077624
#     YR04_15_DESS_prep_VF.mha
#       norm before normalization: 3453.731
#       norm after normalization: 0.0008469959361214398
#       number of image voxels: 23592960
#       snumber of masked voxels: 4077624
#     YR04_16_DESS_prep_VF.mha
#       norm before normalization: 1904.218
#       norm after normalization: 0.0004669920565452148
#       number of image voxels: 23592960
#       snumber of masked voxels: 4077624
#     YR04_17_DESS_prep_VF.mha
#       norm before normalization: 3078.4646
#       norm after normalization: 0.0007549652934182689
#       number of image voxels: 23592960
#       snumber of masked voxels: 4077624
#     YR04_18_DESS_prep_VF.mha
#       norm before normalization: 1403.7797
#       norm after normalization: 0.00034426412613961893
#       number of image voxels: 23592960
#       snumber of masked voxels: 4077624
#     YR04_19_DESS_prep_VF.mha
#       norm before normalization: 2881.9082
#       norm after normalization: 0.0007067616345021022
#       number of image voxels: 23592960
#       snumber of masked voxels: 4077624
#    -> Distances to average field are: [0.00045669 0.0005255  0.00032113 0.00054726 0.00033784 0.00285999
#  0.00046861 0.00028443 0.00016076 0.00272562 0.0011932  0.00078213
#  0.00010236 0.0008136  0.000847   0.00046699 0.00075497 0.00034426
#  0.00070676]
#    -> Minimum distance is 0.00010236
#    -> Reference of next iteration is YR04_13_DESS_prep.mha
# -> The total time for iteration 5 was 698 seconds (about 11 min)
# -> Iteration: 6
#    1. Preparing reference YR04_13_DESS_prep.mha
#    2. Registering images to current reference
# -> Vector fields calculated
#    3. Computing new reference
#     YR04_01_DESS_prep_VF.mha
#       norm before normalization: 1889.0062
#       norm after normalization: 0.0004616239347643557
#       number of image voxels: 23592960
#       snumber of masked voxels: 4092089
#     YR04_02_DESS_prep_VF.mha
#       norm before normalization: 2392.2004
#       norm after normalization: 0.0005845914982428596
#       number of image voxels: 23592960
#       snumber of masked voxels: 4092089
#     YR04_03_DESS_prep_VF.mha
#       norm before normalization: 2143.939
#       norm after normalization: 0.0005239228581889959
#       number of image voxels: 23592960
#       snumber of masked voxels: 4092089
#     YR04_04_DESS_prep_VF.mha
#       norm before normalization: 2489.0796
#       norm after normalization: 0.0006082662400167128
#       number of image voxels: 23592960
#       snumber of masked voxels: 4092089
#     YR04_05_DESS_prep_VF.mha
#       norm before normalization: 2438.2449
#       norm after normalization: 0.000595843558888107
#       number of image voxels: 23592960
#       snumber of masked voxels: 4092089
#     YR04_06_DESS_prep_VF.mha
#       norm before normalization: 8430.819
#       norm after normalization: 0.0020602727203483354
#       number of image voxels: 23592960
#       snumber of masked voxels: 4092089
#     YR04_07_DESS_prep_VF.mha
#       norm before normalization: 2119.3665
#       norm after normalization: 0.0005179179766320149
#       number of image voxels: 23592960
#       snumber of masked voxels: 4092089
#     YR04_08_DESS_prep_VF.mha
#       norm before normalization: 928.51746
#       norm after normalization: 0.00022690548911685144
#       number of image voxels: 23592960
#       snumber of masked voxels: 4092089
#     YR04_09_DESS_prep_VF.mha
#       norm before normalization: 1651.5046
#       norm after normalization: 0.0004035847310925728
#       number of image voxels: 23592960
#       snumber of masked voxels: 4092089
#     YR04_10_DESS_prep_VF.mha
#       norm before normalization: 8687.846
#       norm after normalization: 0.0021230832719241932
#       number of image voxels: 23592960
#       snumber of masked voxels: 4092089
#     YR04_11_DESS_prep_VF.mha
#       norm before normalization: 5608.1133
#       norm after normalization: 0.0013704768594353643
#       number of image voxels: 23592960
#       snumber of masked voxels: 4092089
#     YR04_12_DESS_prep_VF.mha
#       norm before normalization: 2251.3474
#       norm after normalization: 0.0005501706859526699
#       number of image voxels: 23592960
#       snumber of masked voxels: 4092089
#     YR04_13_DESS_prep_VF.mha
#       norm before normalization: 1726.666
#       norm after normalization: 0.00042195221453516775
#       number of image voxels: 23592960
#       snumber of masked voxels: 4092089
#     YR04_14_DESS_prep_VF.mha
#       norm before normalization: 3949.594
#       norm after normalization: 0.0009651779309151451
#       number of image voxels: 23592960
#       snumber of masked voxels: 4092089
#     YR04_15_DESS_prep_VF.mha
#       norm before normalization: 1477.488
#       norm after normalization: 0.0003610596047909454
#       number of image voxels: 23592960
#       snumber of masked voxels: 4092089
#     YR04_16_DESS_prep_VF.mha
#       norm before normalization: 2732.0137
#       norm after normalization: 0.0006676330040414566
#       number of image voxels: 23592960
#       snumber of masked voxels: 4092089
#     YR04_17_DESS_prep_VF.mha
#       norm before normalization: 15281.137
#       norm after normalization: 0.0037343119171528282
#       number of image voxels: 23592960
#       snumber of masked voxels: 4092089
#     YR04_18_DESS_prep_VF.mha
#       norm before normalization: 1414.5166
#       norm after normalization: 0.00034567102562102145
#       number of image voxels: 23592960
#       snumber of masked voxels: 4092089
#     YR04_19_DESS_prep_VF.mha
#       norm before normalization: 2424.2627
#       norm after normalization: 0.0005924266787238743
#       number of image voxels: 23592960
#       snumber of masked voxels: 4092089
#    -> Distances to average field are: [0.00046162 0.00058459 0.00052392 0.00060827 0.00059584 0.00206027
#  0.00051792 0.00022691 0.00040358 0.00212308 0.00137048 0.00055017
#  0.00042195 0.00096518 0.00036106 0.00066763 0.00373431 0.00034567
#  0.00059243]
#    -> Minimum distance is 0.00022691
#    -> Reference of next iteration is YR04_08_DESS_prep.mha
# -> The total time for iteration 6 was 697 seconds (about 11 min)
# -> Iteration: 7
#    1. Preparing reference YR04_08_DESS_prep.mha
#    2. Registering images to current reference
# -> Vector fields calculated
#    3. Computing new reference
#     YR04_01_DESS_prep_VF.mha
#       norm before normalization: 3001.695
#       norm after normalization: 0.000760706040462262
#       number of image voxels: 23592960
#       snumber of masked voxels: 3945933
#     YR04_02_DESS_prep_VF.mha
#       norm before normalization: 5007.4873
#       norm after normalization: 0.0012690249187422848
#       number of image voxels: 23592960
#       snumber of masked voxels: 3945933
#     YR04_03_DESS_prep_VF.mha
#       norm before normalization: 5470.292
#       norm after normalization: 0.00138631142297335
#       number of image voxels: 23592960
#       snumber of masked voxels: 3945933
#     YR04_04_DESS_prep_VF.mha
#       norm before normalization: 5313.222
#       norm after normalization: 0.0013465059259670019
#       number of image voxels: 23592960
#       snumber of masked voxels: 3945933
#     YR04_05_DESS_prep_VF.mha
#       norm before normalization: 5338.1836
#       norm after normalization: 0.001352831787501207
#       number of image voxels: 23592960
#       snumber of masked voxels: 3945933
#     YR04_06_DESS_prep_VF.mha
#       norm before normalization: 7506.435
#       norm after normalization: 0.0019023219752068142
#       number of image voxels: 23592960
#       snumber of masked voxels: 3945933
#     YR04_07_DESS_prep_VF.mha
#       norm before normalization: 5076.762
#       norm after normalization: 0.0012865809447426628
#       number of image voxels: 23592960
#       snumber of masked voxels: 3945933
#     YR04_08_DESS_prep_VF.mha
#       norm before normalization: 3115.429
#       norm after normalization: 0.0007895291063173463
#       number of image voxels: 23592960
#       snumber of masked voxels: 3945933
#     YR04_09_DESS_prep_VF.mha
#       norm before normalization: 1597.3046
#       norm after normalization: 0.0004047976905410425
#       number of image voxels: 23592960
#       snumber of masked voxels: 3945933
#     YR04_10_DESS_prep_VF.mha
#       norm before normalization: 11095.336
#       norm after normalization: 0.002811840935337726
#       number of image voxels: 23592960
#       snumber of masked voxels: 3945933
#     YR04_11_DESS_prep_VF.mha
#       norm before normalization: 6570.6143
#       norm after normalization: 0.0016651611311729064
#       number of image voxels: 23592960
#       snumber of masked voxels: 3945933
#     YR04_12_DESS_prep_VF.mha
#       norm before normalization: 2510.5452
#       norm after normalization: 0.0006362361362992288
#       number of image voxels: 23592960
#       snumber of masked voxels: 3945933
#     YR04_13_DESS_prep_VF.mha
#       norm before normalization: 4039.277
#       norm after normalization: 0.0010236557740867305
#       number of image voxels: 23592960
#       snumber of masked voxels: 3945933
#     YR04_14_DESS_prep_VF.mha
#       norm before normalization: 9509.227
#       norm after normalization: 0.002409880391405531
#       number of image voxels: 23592960
#       snumber of masked voxels: 3945933
#     YR04_15_DESS_prep_VF.mha
#       norm before normalization: 13297.794
#       norm after normalization: 0.003369999932921441
#       number of image voxels: 23592960
#       snumber of masked voxels: 3945933
#     YR04_16_DESS_prep_VF.mha
#       norm before normalization: 9254.079
#       norm after normalization: 0.0023452195213559124
#       number of image voxels: 23592960
#       snumber of masked voxels: 3945933
#     YR04_17_DESS_prep_VF.mha
#       norm before normalization: 4565.0464
#       norm after normalization: 0.0011568991127621148
#       number of image voxels: 23592960
#       snumber of masked voxels: 3945933
#     YR04_18_DESS_prep_VF.mha
#       norm before normalization: 3408.2844
#       norm after normalization: 0.0008637461466852389
#       number of image voxels: 23592960
#       snumber of masked voxels: 3945933
#     YR04_19_DESS_prep_VF.mha
#       norm before normalization: 1977.7682
#       norm after normalization: 0.0005012168702500935
#       number of image voxels: 23592960
#       snumber of masked voxels: 3945933
#    -> Distances to average field are: [0.00076071 0.00126902 0.00138631 0.00134651 0.00135283 0.00190232
#  0.00128658 0.00078953 0.0004048  0.00281184 0.00166516 0.00063624
#  0.00102366 0.00240988 0.00337    0.00234522 0.0011569  0.00086375
#  0.00050122]
#    -> Minimum distance is 0.00040480
#    -> Reference of next iteration is YR04_09_DESS_prep.mha
# -> The total time for iteration 7 was 708 seconds (about 11 min)
# -> Iteration: 8
#    1. Preparing reference YR04_09_DESS_prep.mha
#    2. Registering images to current reference
# -> Vector fields calculated
#    3. Computing new reference
#     YR04_01_DESS_prep_VF.mha
#       norm before normalization: 1862.1902
#       norm after normalization: 0.00045668511504417153
#       number of image voxels: 23592960
#       snumber of masked voxels: 4077624
#     YR04_02_DESS_prep_VF.mha
#       norm before normalization: 2142.7751
#       norm after normalization: 0.0005254960110310257
#       number of image voxels: 23592960
#       snumber of masked voxels: 4077624
#     YR04_03_DESS_prep_VF.mha
#       norm before normalization: 1309.4329
#       norm after normalization: 0.0003211264357204404
#       number of image voxels: 23592960
#       snumber of masked voxels: 4077624
#     YR04_04_DESS_prep_VF.mha
#       norm before normalization: 2231.5098
#       norm after normalization: 0.0005472573649814205
#       number of image voxels: 23592960
#       snumber of masked voxels: 4077624
#     YR04_05_DESS_prep_VF.mha
#       norm before normalization: 1377.5864
#       norm after normalization: 0.00033784047420293045
#       number of image voxels: 23592960
#       snumber of masked voxels: 4077624
#     YR04_06_DESS_prep_VF.mha
#       norm before normalization: 11661.962
#       norm after normalization: 0.002859989521854516
#       number of image voxels: 23592960
#       snumber of masked voxels: 4077624
#     YR04_07_DESS_prep_VF.mha
#       norm before normalization: 1910.7982
#       norm after normalization: 0.00046860579047343197
#       number of image voxels: 23592960
#       snumber of masked voxels: 4077624
#     YR04_08_DESS_prep_VF.mha
#       norm before normalization: 1159.8011
#       norm after normalization: 0.0002844306261344689
#       number of image voxels: 23592960
#       snumber of masked voxels: 4077624
#     YR04_09_DESS_prep_VF.mha
#       norm before normalization: 655.5014
#       norm after normalization: 0.00016075572534608235
#       number of image voxels: 23592960
#       snumber of masked voxels: 4077624
#     YR04_10_DESS_prep_VF.mha
#       norm before normalization: 11114.051
#       norm after normalization: 0.0027256193266593487
#       number of image voxels: 23592960
#       snumber of masked voxels: 4077624
#     YR04_11_DESS_prep_VF.mha
#       norm before normalization: 4865.434
#       norm after normalization: 0.0011932032188429463
#       number of image voxels: 23592960
#       snumber of masked voxels: 4077624
#     YR04_12_DESS_prep_VF.mha
#       norm before normalization: 3189.215
#       norm after normalization: 0.0007821258379611816
#       number of image voxels: 23592960
#       snumber of masked voxels: 4077624
#     YR04_13_DESS_prep_VF.mha
#       norm before normalization: 417.36624
#       norm after normalization: 0.00010235525429884612
#       number of image voxels: 23592960
#       snumber of masked voxels: 4077624
#     YR04_14_DESS_prep_VF.mha
#       norm before normalization: 3317.572
#       norm after normalization: 0.0008136042022227589
#       number of image voxels: 23592960
#       snumber of masked voxels: 4077624
#     YR04_15_DESS_prep_VF.mha
#       norm before normalization: 3453.731
#       norm after normalization: 0.0008469959361214398
#       number of image voxels: 23592960
#       snumber of masked voxels: 4077624
#     YR04_16_DESS_prep_VF.mha
#       norm before normalization: 1904.218
#       norm after normalization: 0.0004669920565452148
#       number of image voxels: 23592960
#       snumber of masked voxels: 4077624
#     YR04_17_DESS_prep_VF.mha
#       norm before normalization: 3078.4646
#       norm after normalization: 0.0007549652934182689
#       number of image voxels: 23592960
#       snumber of masked voxels: 4077624
#     YR04_18_DESS_prep_VF.mha
#       norm before normalization: 1403.7797
#       norm after normalization: 0.00034426412613961893
#       number of image voxels: 23592960
#       snumber of masked voxels: 4077624
#     YR04_19_DESS_prep_VF.mha
#       norm before normalization: 2881.9082
#       norm after normalization: 0.0007067616345021022
#       number of image voxels: 23592960
#       snumber of masked voxels: 4077624
#    -> Distances to average field are: [0.00045669 0.0005255  0.00032113 0.00054726 0.00033784 0.00285999
#  0.00046861 0.00028443 0.00016076 0.00272562 0.0011932  0.00078213
#  0.00010236 0.0008136  0.000847   0.00046699 0.00075497 0.00034426
#  0.00070676]
#    -> Minimum distance is 0.00010236
#    -> Reference of next iteration is YR04_13_DESS_prep.mha
# -> The total time for iteration 8 was 699 seconds (about 11 min)
# -> Iteration: 9
#    1. Preparing reference YR04_13_DESS_prep.mha
#    2. Registering images to current reference
# -> Vector fields calculated
#    3. Computing new reference
#     YR04_01_DESS_prep_VF.mha
#       norm before normalization: 1889.0062
#       norm after normalization: 0.0004616239347643557
#       number of image voxels: 23592960
#       snumber of masked voxels: 4092089
#     YR04_02_DESS_prep_VF.mha
#       norm before normalization: 2392.2004
#       norm after normalization: 0.0005845914982428596
#       number of image voxels: 23592960
#       snumber of masked voxels: 4092089
#     YR04_03_DESS_prep_VF.mha
#       norm before normalization: 2143.939
#       norm after normalization: 0.0005239228581889959
#       number of image voxels: 23592960
#       snumber of masked voxels: 4092089
#     YR04_04_DESS_prep_VF.mha
#       norm before normalization: 2489.0796
#       norm after normalization: 0.0006082662400167128
#       number of image voxels: 23592960
#       snumber of masked voxels: 4092089
#     YR04_05_DESS_prep_VF.mha
#       norm before normalization: 2438.2449
#       norm after normalization: 0.000595843558888107
#       number of image voxels: 23592960
#       snumber of masked voxels: 4092089
#     YR04_06_DESS_prep_VF.mha
#       norm before normalization: 8430.819
#       norm after normalization: 0.0020602727203483354
#       number of image voxels: 23592960
#       snumber of masked voxels: 4092089
#     YR04_07_DESS_prep_VF.mha
#       norm before normalization: 2119.3665
#       norm after normalization: 0.0005179179766320149
#       number of image voxels: 23592960
#       snumber of masked voxels: 4092089
#     YR04_08_DESS_prep_VF.mha
#       norm before normalization: 928.51746
#       norm after normalization: 0.00022690548911685144
#       number of image voxels: 23592960
#       snumber of masked voxels: 4092089
#     YR04_09_DESS_prep_VF.mha
#       norm before normalization: 1651.5046
#       norm after normalization: 0.0004035847310925728
#       number of image voxels: 23592960
#       snumber of masked voxels: 4092089
#     YR04_10_DESS_prep_VF.mha
#       norm before normalization: 8687.846
#       norm after normalization: 0.0021230832719241932
#       number of image voxels: 23592960
#       snumber of masked voxels: 4092089
#     YR04_11_DESS_prep_VF.mha
#       norm before normalization: 5608.1133
#       norm after normalization: 0.0013704768594353643
#       number of image voxels: 23592960
#       snumber of masked voxels: 4092089
#     YR04_12_DESS_prep_VF.mha
#       norm before normalization: 2251.3474
#       norm after normalization: 0.0005501706859526699
#       number of image voxels: 23592960
#       snumber of masked voxels: 4092089
#     YR04_13_DESS_prep_VF.mha
#       norm before normalization: 1726.666
#       norm after normalization: 0.00042195221453516775
#       number of image voxels: 23592960
#       snumber of masked voxels: 4092089
#     YR04_14_DESS_prep_VF.mha
#       norm before normalization: 3949.594
#       norm after normalization: 0.0009651779309151451
#       number of image voxels: 23592960
#       snumber of masked voxels: 4092089
#     YR04_15_DESS_prep_VF.mha
#       norm before normalization: 1477.488
#       norm after normalization: 0.0003610596047909454
#       number of image voxels: 23592960
#       snumber of masked voxels: 4092089
#     YR04_16_DESS_prep_VF.mha
#       norm before normalization: 2732.0137
#       norm after normalization: 0.0006676330040414566
#       number of image voxels: 23592960
#       snumber of masked voxels: 4092089
#     YR04_17_DESS_prep_VF.mha
#       norm before normalization: 15281.137
#       norm after normalization: 0.0037343119171528282
#       number of image voxels: 23592960
#       snumber of masked voxels: 4092089
#     YR04_18_DESS_prep_VF.mha
#       norm before normalization: 1414.5166
#       norm after normalization: 0.00034567102562102145
#       number of image voxels: 23592960
#       snumber of masked voxels: 4092089
#     YR04_19_DESS_prep_VF.mha
#       norm before normalization: 2424.2627
#       norm after normalization: 0.0005924266787238743
#       number of image voxels: 23592960
#       snumber of masked voxels: 4092089
#    -> Distances to average field are: [0.00046162 0.00058459 0.00052392 0.00060827 0.00059584 0.00206027
#  0.00051792 0.00022691 0.00040358 0.00212308 0.00137048 0.00055017
#  0.00042195 0.00096518 0.00036106 0.00066763 0.00373431 0.00034567
#  0.00059243]
#    -> Minimum distance is 0.00022691
#    -> Reference of next iteration is YR04_08_DESS_prep.mha
# -> The total time for iteration 9 was 698 seconds (about 11 min)

# %% [markdown]
# ## Show results
# The graph shows the images whose distance to the average vector field is the minimum, at each iteration. The image at the current iteration is used as the reference image for the following iteration.

# %%
find.plot_convergence(reference_names, min_distances)

# %% [markdown]
# ### Dependencies

# %%
# %load_ext watermark
# %watermark -v -m -p SimpleITK,numpy,matplotlib,multiprocessing
# Out:
# CPython 3.6.1
# IPython 6.4.0
#
# SimpleITK unknown
# numpy 1.14.5
# matplotlib 2.2.2
# multiprocessing unknown
#
# compiler   : GCC 4.8.5 20150623 (Red Hat 4.8.5-11)
# system     : Linux
# release    : 3.10.0-957.1.3.el7.x86_64
# machine    : x86_64
# processor  : x86_64
# CPU cores  : 20
# interpreter: 64bit
