# %% [markdown]
# ## [pyKNEEr](https://github.com/sbonaretti/pyKNEEr)

# %% [markdown]
# # [Segmentation quality](https://sbonaretti.github.io/pyKNEEr/segmentation.html)

# %% [markdown]
# Segmentation quality is evaluated using 3 overlap agreement measures [1]:
# - Dice coefficient
# - Jaccard coefficient
# - Volume similarity
#
# and one measure of surface distance

# %% [markdown]
# ---

# %% [markdown]
# *Automatic data download for the reproducibility of this notebook:*
# - Download input images from Zenodo and image file list from GitHub:

# %%
import os
import wget
from zipfile import ZipFile

# %%
# local folder  
local_folder_name  = "./OAI2/"
# Zenodo variables
input_URL          = "https://zenodo.org/record/2583184/files/"
zipped_folder_name = "OAI2_segmented.zip" 
zipped_gt_name     = "OAI2_segmented_IM.zip"
local_gt_name      = "/segmented_IM"
# GitHub variables
raw_url            = "https://raw.githubusercontent.com/sbonaretti/pyKNEEr/master/publication/data/"
input_file_name    = "image_list_segmentation_quality_OAI2_FU.txt"

# %%
# create local folder for dataset
if not os.path.isdir(local_folder_name):
    os.mkdir(local_folder_name)
    print ("folder " + local_folder_name + " created")

# %%
# download zipped folder from Zenodo
wget.download(input_URL + zipped_folder_name, local_folder_name + zipped_folder_name)

# %%
# download ground truth images
wget.download(input_URL + zipped_gt_name, local_folder_name + zipped_gt_name)

# %%
# unzip image folder
with ZipFile(local_folder_name + zipped_folder_name, 'r') as zip: 
    zip.extractall(local_folder_name)

# %%
# unzip ground truth images
with ZipFile(local_folder_name + zipped_gt_name, 'r') as zip: 
    zip.extractall(local_folder_name)

# %%
# download input file from GitHub
wget.download(raw_url + input_file_name, "./" + input_file_name)

# %% [markdown]
# ---

# %% [markdown]
# ## Import packages

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from pykneer import pykneer_io                  as io
from pykneer import segmentation_quality_for_nb as sq

# %% [markdown]
# ## Image information

# %% [markdown]
# Input and output:
# - `input_file_name` contains the list of the masks segmented using pyKNEEr and of ground truth masks
# - `output_file_name` contains the table of the overlap coefficients

# %%
# input_file_name  = "./image_list_segmentation_quality_OAI2_FU.txt" # commented out because downloaded from GitHub
input_file_name            = "/Volumes/SereHD/work/data_pyKNEEr/image_list_segmentation_quality_OAI2_FU.txt"
output_file_name_overlap   = "overlapCoeff_OAI2_FU.csv"
output_file_name_distances = "average_distances_OAI2_FU.csv"

# %% [markdown]
# #### Reading image data
# - `image_data` is a dictionary (or struct), where each cell corresponds to an image. For each image, information such as paths and file names are stored

# %%
image_data = io.load_image_data_segmentation_quality(input_file_name)
# Out:
# -> image information loaded

# %% [markdown]
# ---

# %% [markdown]
# ## Calculating overlap coefficients

# %%
dice_coeff, jacc_coeff, vol_simil = sq.compute_overlap(image_data)

# %% [markdown]
# ## Visualizing overlap coefficients
#
# The values of overlap coefficient are visualized as:
# - a GRAPH, to visually observe the trend of the dataset
# - a TABLE, to observe the numerical values

# %% [markdown]
# #### GRAPH: Dots represent the coefficient value

# %%
sq.overlap_coeff_graph(image_data, dice_coeff, jacc_coeff, vol_simil)

# %% [markdown]
# #### TABLE: Overlap coefficients per image
# The table is saved as a .csv file for subsequent analyisis

# %%
coeff = sq.overlap_coeff_table(image_data, dice_coeff, jacc_coeff, vol_simil, output_file_name_overlap)
display(coeff)
# Out:
# Table saved as: overlapCoeff_OAI2_FU.csv
#           subjects  dice_coeff  jaccard_coeff  volume_similarity
# 1   001_FU_prep_fc        0.70           0.53              -0.08
# 2   002_FU_prep_fc        0.76           0.61              -0.08
# 3   003_FU_prep_fc        0.75           0.60              -0.26
# 4   004_FU_prep_fc        0.74           0.58              -0.15
# 5   005_FU_prep_fc        0.78           0.63              -0.18
# 6   006_FU_prep_fc        0.01           0.01              -0.56
# 7   007_FU_prep_fc        0.72           0.56              -0.07
# 8   008_FU_prep_fc        0.70           0.54               0.03
# 9   009_FU_prep_fc        0.71           0.56               0.09
# 10  010_FU_prep_fc        0.70           0.54               0.01
# 11  011_FU_prep_fc        0.75           0.60              -0.11
# 12  012_FU_prep_fc        0.72           0.56              -0.00
# 13  013_FU_prep_fc        0.78           0.64              -0.02
# 14  014_FU_prep_fc        0.77           0.63              -0.11
# 15  015_FU_prep_fc        0.82           0.70              -0.10
# 16  016_FU_prep_fc        0.83           0.70              -0.11
# 17  017_FU_prep_fc        0.70           0.54              -0.04
# 18  018_FU_prep_fc        0.75           0.61              -0.21
# 19  019_FU_prep_fc        0.70           0.54              -0.02
# 20  020_FU_prep_fc        0.74           0.59              -0.13
# 21  021_FU_prep_fc        0.72           0.56              -0.33
# 22  022_FU_prep_fc        0.65           0.48              -0.17
# 23  023_FU_prep_fc        0.75           0.60              -0.11
# 24  024_FU_prep_fc        0.34           0.20              -0.44
# 25  025_FU_prep_fc        0.69           0.52              -0.04
# 26  026_FU_prep_fc        0.69           0.53               0.21
# 27  027_FU_prep_fc        0.76           0.61              -0.21
# 28  028_FU_prep_fc        0.70           0.54              -0.01
# 29  029_FU_prep_fc        0.73           0.58              -0.14
# 30  030_FU_prep_fc        0.70           0.54              -0.07
# 31  031_FU_prep_fc        0.56           0.39              -0.40
# 32  032_FU_prep_fc        0.75           0.61              -0.13
# 33  033_FU_prep_fc        0.64           0.48              -0.17
# 34  034_FU_prep_fc        0.67           0.50              -0.28
# 35  035_FU_prep_fc        0.68           0.52              -0.28
# 36  036_FU_prep_fc        0.72           0.57              -0.15
# 37  037_FU_prep_fc        0.79           0.65              -0.14
# 38  038_FU_prep_fc        0.72           0.57               0.01
# 39  039_FU_prep_fc        0.73           0.58              -0.24
# 40  040_FU_prep_fc        0.74           0.59              -0.05
# 41  041_FU_prep_fc        0.71           0.54              -0.06
# 42  042_FU_prep_fc        0.72           0.57              -0.08
# 43  043_FU_prep_fc        0.73           0.57              -0.13
# 44  044_FU_prep_fc        0.76           0.61              -0.21
# 45  045_FU_prep_fc        0.75           0.60              -0.05
# 46  046_FU_prep_fc        0.75           0.60              -0.06
# 47  047_FU_prep_fc        0.74           0.59               0.05
# 48  048_FU_prep_fc        0.77           0.63              -0.06
# 49  049_FU_prep_fc        0.74           0.58              -0.13
# 50  050_FU_prep_fc        0.71           0.56              -0.07
# 51  051_FU_prep_fc        0.63           0.46               0.00
# 52  052_FU_prep_fc        0.77           0.63               0.06
# 53  053_FU_prep_fc        0.63           0.46               0.13
# 54  054_FU_prep_fc        0.79           0.65              -0.14
# 55  055_FU_prep_fc        0.78           0.64              -0.12
# 56  056_FU_prep_fc        0.74           0.58               0.03
# 57  057_FU_prep_fc        0.41           0.26              -0.27
# 58  058_FU_prep_fc        0.70           0.54              -0.11
# 59  059_FU_prep_fc        0.76           0.61              -0.00
# 60  060_FU_prep_fc        0.65           0.48              -0.07
# 61  061_FU_prep_fc        0.68           0.52               0.07
# 62  062_FU_prep_fc        0.74           0.59               0.01
# 63  063_FU_prep_fc        0.69           0.52              -0.01
# 64  064_FU_prep_fc        0.69           0.53              -0.12
# 65  065_FU_prep_fc        0.79           0.65              -0.04
# 66  066_FU_prep_fc        0.73           0.58              -0.04
# 67  067_FU_prep_fc        0.72           0.56              -0.16
# 68  068_FU_prep_fc        0.67           0.51              -0.21
# 69  069_FU_prep_fc        0.75           0.60              -0.10
# 70  070_FU_prep_fc        0.71           0.55              -0.24
# 71  071_FU_prep_fc        0.72           0.56              -0.11
# 72  072_FU_prep_fc        0.70           0.54              -0.09
# 73  073_FU_prep_fc        0.75           0.60              -0.11
# 74  074_FU_prep_fc        0.73           0.57              -0.04
# 75  075_FU_prep_fc        0.79           0.66              -0.10
# 76  076_FU_prep_fc        0.66           0.49               0.30
# 77  077_FU_prep_fc        0.64           0.47              -0.10
# 78  078_FU_prep_fc        0.73           0.58               0.02
# 79  079_FU_prep_fc        0.80           0.66              -0.09
# 80  080_FU_prep_fc        0.64           0.47              -0.25
# 81  081_FU_prep_fc        0.71           0.55              -0.20
# 82  082_FU_prep_fc        0.70           0.54              -0.02
# 83  083_FU_prep_fc        0.68           0.52               0.12
# 84  084_FU_prep_fc        0.59           0.42              -0.24
# 85  085_FU_prep_fc        0.78           0.64              -0.05
# 86  086_FU_prep_fc        0.70           0.54              -0.04
# 87  087_FU_prep_fc        0.73           0.57               0.03
# 88  088_FU_prep_fc        0.75           0.60              -0.13

# %% [markdown]
# ---

# %% [markdown]
# ## Calculating surface distances

# %%
mean_distances, stddev_distances = sq.compute_surface_distance(image_data)

# %% [markdown]
# ## Visualizing surface distances
#
# The values of surface distances are visualized as:
# - a GRAPH, to visually observe the trend of the dataset
# - a TABLE, to observe the numerical values

# %% [markdown]
# #### GRAPH: Dots represent the mean surface distance

# %%
sq.surface_distance_graph(image_data, mean_distances, stddev_distances)

# %% [markdown]
# #### TABLE: Average distances per image
# The table is saved as a .csv file for subsequent analyisis

# %%
table = sq.surface_distance_table(image_data, mean_distances, stddev_distances, output_file_name_distances)
display(table)
# Out:
# Table saved as: average_distances_OAI2_FU.csv
#           subjects  mean_distances  stddev_distances
# 1   001_FU_prep_fc            1.55              2.30
# 2   002_FU_prep_fc            0.95              1.54
# 3   003_FU_prep_fc            1.45              2.25
# 4   004_FU_prep_fc            1.51              2.52
# 5   005_FU_prep_fc            1.27              2.28
# 6   006_FU_prep_fc           61.36             30.04
# 7   007_FU_prep_fc            1.31              1.78
# 8   008_FU_prep_fc            1.23              1.86
# 9   009_FU_prep_fc            1.63              2.97
# 10  010_FU_prep_fc            1.12              2.27
# 11  011_FU_prep_fc            1.35              2.14
# 12  012_FU_prep_fc            1.80              2.63
# 13  013_FU_prep_fc            1.24              2.15
# 14  014_FU_prep_fc            0.91              1.49
# 15  015_FU_prep_fc            0.93              1.87
# 16  016_FU_prep_fc            0.85              1.41
# 17  017_FU_prep_fc            1.57              2.56
# 18  018_FU_prep_fc            1.00              1.82
# 19  019_FU_prep_fc            1.99              3.26
# 20  020_FU_prep_fc            1.25              2.12
# 21  021_FU_prep_fc            1.55              2.61
# 22  022_FU_prep_fc            1.90              3.16
# 23  023_FU_prep_fc            1.30              2.22
# 24  024_FU_prep_fc            5.58              8.20
# 25  025_FU_prep_fc            1.54              2.33
# 26  026_FU_prep_fc            1.36              1.88
# 27  027_FU_prep_fc            1.06              1.55
# 28  028_FU_prep_fc            1.61              2.67
# 29  029_FU_prep_fc            1.33              2.22
# 30  030_FU_prep_fc            1.95              4.33
# 31  031_FU_prep_fc            8.06             13.72
# 32  032_FU_prep_fc            1.23              2.13
# 33  033_FU_prep_fc            1.85              3.07
# 34  034_FU_prep_fc            2.12              3.02
# 35  035_FU_prep_fc            2.16              3.40
# 36  036_FU_prep_fc            1.01              1.43
# 37  037_FU_prep_fc            0.89              1.46
# 38  038_FU_prep_fc            1.49              2.43
# 39  039_FU_prep_fc            1.45              2.62
# 40  040_FU_prep_fc            1.07              1.62
# 41  041_FU_prep_fc            1.38              2.18
# 42  042_FU_prep_fc            1.17              1.64
# 43  043_FU_prep_fc            1.16              2.17
# 44  044_FU_prep_fc            1.45              2.54
# 45  045_FU_prep_fc            1.15              1.84
# 46  046_FU_prep_fc            1.30              2.09
# 47  047_FU_prep_fc            1.03              1.69
# 48  048_FU_prep_fc            0.93              1.34
# 49  049_FU_prep_fc            1.27              1.94
# 50  050_FU_prep_fc            1.48              2.54
# 51  051_FU_prep_fc            1.63              1.95
# 52  052_FU_prep_fc            1.01              1.55
# 53  053_FU_prep_fc            1.39              1.98
# 54  054_FU_prep_fc            0.98              1.57
# 55  055_FU_prep_fc            1.04              1.86
# 56  056_FU_prep_fc            1.29              2.06
# 57  057_FU_prep_fc            4.49              5.93
# 58  058_FU_prep_fc            1.14              1.84
# 59  059_FU_prep_fc            1.10              1.65
# 60  060_FU_prep_fc            1.64              2.42
# 61  061_FU_prep_fc            2.08              4.77
# 62  062_FU_prep_fc            1.46              2.25
# 63  063_FU_prep_fc            1.62              2.28
# 64  064_FU_prep_fc            1.41              2.14
# 65  065_FU_prep_fc            0.96              1.21
# 66  066_FU_prep_fc            1.32              2.12
# 67  067_FU_prep_fc            1.46              2.47
# 68  068_FU_prep_fc            2.11              3.37
# 69  069_FU_prep_fc            1.07              1.63
# 70  070_FU_prep_fc            1.67              2.96
# 71  071_FU_prep_fc            1.47              2.60
# 72  072_FU_prep_fc            1.49              2.38
# 73  073_FU_prep_fc            1.01              1.76
# 74  074_FU_prep_fc            1.13              1.64
# 75  075_FU_prep_fc            0.93              1.40
# 76  076_FU_prep_fc            1.74              2.29
# 77  077_FU_prep_fc            2.14              4.30
# 78  078_FU_prep_fc            1.37              2.32
# 79  079_FU_prep_fc            1.19              1.93
# 80  080_FU_prep_fc            1.90              3.74
# 81  081_FU_prep_fc            1.53              2.43
# 82  082_FU_prep_fc            1.16              1.70
# 83  083_FU_prep_fc            1.90              2.98
# 84  084_FU_prep_fc            2.81              4.10
# 85  085_FU_prep_fc            1.21              2.01
# 86  086_FU_prep_fc            1.52              2.40
# 87  087_FU_prep_fc            1.08              1.46
# 88  088_FU_prep_fc            1.16              1.58

# %% [markdown]
# ---

# %% [markdown]
# ### References

# %% [markdown]
# [1] Tustison N.J., Gee J.C. [*Introducing Dice, Jaccard, and Other Label Overlap Measures To ITK*](http://insight-journal.org/browse/publication/707) The Insight Journal. July-December. 2009.

# %% [markdown]
# ### Dependencies

# %%
# %load_ext watermark
# %watermark -v -m -p pykneer,SimpleITK,matplotlib,numpy,pandas
print (" ")
# %watermark -u -n -t -z
# Out:
# CPython 3.7.3
# IPython 7.8.0
#
# pykneer 0.0.4
# SimpleITK 1.2.2
# matplotlib 3.1.1
# numpy 1.17.2
# pandas 0.25.1
#
# compiler   : Clang 4.0.1 (tags/RELEASE_401/final)
# system     : Darwin
# release    : 17.7.0
# machine    : x86_64
# processor  : i386
# CPU cores  : 4
# interpreter: 64bit
#
# last updated: Mon Oct 14 2019 12:27:27 CEST
